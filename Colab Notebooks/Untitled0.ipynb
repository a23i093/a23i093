# %%
#数値型(int)

my_var=16

#浮動小数点型(float)
my_var = 12.16
my_var = 1.216E1

# %% [markdown]
# 3-1-2. 実践演習
# １）変数xに300を入れ、その変数を出力せよ
#
# ２）変数xに3.14を入れて、その変数を出力せよ

# %%
x = 300
print("x=", x)

x = 3.14
print("x=", x)
# Out:
# x= 300
# x= 3.14

# %% [markdown]
# 3-7-2. 実践演習
# while文を利用して10から５0までの間の偶数のみを出力せよ

# %%
count=10
while count <= 50:
  if count / 2 == 0:
    print(count)
  count += 1
print("終了")
# Out:
#   File "<ipython-input-2-d7d370a9f71f>", line 2
#     while count =< 50:
#                 ^
# SyntaxError: invalid syntax
