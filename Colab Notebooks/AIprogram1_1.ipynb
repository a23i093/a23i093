# %% [markdown]
# # 2 プログラミング入門

# %% [markdown]
# 2.1 整数を使った計算(プログラムとしては使わないですが)

# %% [markdown]
# (1)整数型
#
#
# ```
# 341
# ```

# %%
93
# Out:
# 93

# %% [markdown]
# (2)演算子(2+3*4)

# %%
2+3*4
# Out:
# 14

# %% [markdown]
# (3)括弧による計算((2+3)*4)

# %%
(2+3)*4
# Out:
# 20

# %% [markdown]
# (4)割り算
#
#
# ```
# 4/2
# ```
# 結果が小数点になるので、小数型になっています。

# %%
4/2
# Out:
# 2.0

# %% [markdown]
# (5) //を使った場合
#
#
# ```
# 4//3
# ```
#  /が2つの場合は、結果が整数となる

# %%
4//3
# Out:
# 1

# %% [markdown]
# (6)余りの計算(5%3)

# %%
5%3
# Out:
# 2

# %% [markdown]
# (7)べき乗(2**6)

# %%
2**6
# Out:
# 64

# %% [markdown]
# (8)大きな数(2**607-1)

# %%
2**607-1
# Out:
# 531137992816767098689588206552468627329593117727031923199444138200403559860852242739162502265229285668889329486246501015346579337652707239409519978766587351943831270835393219031728127

# %% [markdown]
# 2.2変数の使い方

# %% [markdown]
# (1)データと変数<br>
# a=10

# %%
a=10

# %% [markdown]
# (2)変数の出力
# <br>
# print("変数の結果＝", a)

# %%
print("変数の結果＝", a)
# Out:
# 変数の結果＝ 10

# %% [markdown]
# (3)変数の変更<br>
#
# ```
# a=a*2
# print("変数の結果",a)
# ```

# %%
a=a*2
print("変数の結果",a)
# Out:
# 変数の結果 20

# %% [markdown]
# (3)変数の命名の注意<br>
# (文法エラーとなるので注意せよ、forなどの文法に使われる単語は変数に使えない)<br>
#
#
# ```
# for = 40
# ```
#
# \#を付けると、その行はコメント扱いになり、プログラムとして処理されない

# %%
#for = 40

# %% [markdown]
# 2.4 組み込み関数<br>

# %% [markdown]
# (1)データの型を調べる<bf>
# ```
# type(a)
# ```
# aは、前のセルで、aに20をいれているので、整数型intになる

# %%
type(a)
# Out:
# int

# %% [markdown]
# (2)上からの実行で一度も使われていない変数の型を調べる.実行時のエラーになるので注意
#
#
# ```
# # type(b)
# ```

# %%
# type(b)

# %% [markdown]
# (3)先にbに3.1をいれておくと、type(b)は、エラーにならない。
# ```
# b=3
# type(b)
# ```

# %%
b=3.1
type(b)
# Out:
# float

# %% [markdown]
# (4)整数への変換int()<br>
# int(c)の整数部分を取り出す
#
#
# ```
# c=3.5
# d=int(c)
# print("d=",d)
# ```

# %%
c=3.5
d=int(c)
print("d=",d)
# Out:
# d= 3

# %% [markdown]
# (5)入出力<br>
# 特に出力 print<br>
# C言語のprintfと似ているけど、違うので注意
#
#
# ```
# print("結果", a)
# ```

# %%
print("変数の 結果", a)
# Out:
# 変数の 結果 20

# %% [markdown]
# # 課題1 下記のプログラムが実行結果になるようにしなさい。<br>
# ![image.png](data:image/png;base64,...)

# %%
#ここに課題1のプログラムを書く
a=2
b=3
a=a*4+b
print("変数aの結果",a)
# Out:
# 変数aの結果 11

# %% [markdown]
# # 課題2<br>
# C=3.14の小数点以下1桁目を出力するプログラムを作成せよ。

# %%
#ここに課題2のプログラムを書く
c=3.14
d= int(c * 10) - int(c) * 10
print("変数dの結果",d)
# Out:
# 変数dの結果 1
