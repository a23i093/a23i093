# %% [markdown]
# # 3. 制御構文

# %% [markdown]
# #3.1 if文

# %% [markdown]
# (1)単純なif文<br>
# 書き方に注意しなさい。インデント字下げでifの範囲が分かる

# %%
a=15
if(a>=10):
  print("結果1")
# Out:
# 結果1

# %% [markdown]
# aの値が違う場合

# %%
a=-1
if(1>=10):
  print("結果1")

# %% [markdown]
# (2)if文 if elseの場合

# %%
b=666
if(b<0):
  print("bは負")
else:
  print("bは0以上")
# Out:
# bは0以上

# %% [markdown]
# (3)if文 if else 複数処理がある場合

# %%
c=-1
if(c==0):
  a=1
  b=-1
else:
  a=-1
  b=1
print("a=",a)
print("b=",b)
# Out:
# a= -1
# b= 1

# %% [markdown]
# (4)ifの中にifがある場合

# %%
a=1
b=-1
if(a>0):
  if(b>0):
    print("ともに正")
  else:
    print("aが正、bが負")
else:
  if(b>0):
    print("aが負、bが正")
  else:
    print("ともに負")
print("a=",a)
print("b=",b)
# Out:
# aが正、bが負
# a= 1
# b= -1

# %% [markdown]
# (5)入力を判定する

# %%
a=input()
print("a=",a)
b=int(a)
if b>0:
  print("入力は正")
else:
  print("入力は正ではありません")
# Out:
# -11
# a= -11
# 入力は正ではありません

# %% [markdown]
# (6)2つの入力を判定する。if ～ elif ～ else .

# %%
a=int(input())
b=int(input())
print("a=",a)
print("b=",b)

if a>b:
  print("a>b")
elif a==b:
  print("a==b")
else:
  print("a<b")
print("となります")
# Out:
# 5
# 5
# a= 5
# b= 5
# a==b
# となります

# %% [markdown]
# 課題4 入力が10より大きいときに"X"を、<br>
# 0より小さいとき"Y"を、それ以外"Z"を<br>
# 出力するプログラムを作成せよ。

# %%
#課題4のプログラムをここに書く
a=int(input())
if a>10:
  print("X")
elif a<0:
  print("Y")
else:
  print("Z")
# Out:
# 7
# Z

# %% [markdown]
# 課題5 ２つの入力について、2つ値の差を出力するプログラムを作成せよ。<br>
# 例　入力a=10, 入力b=3  差c=7<br>
# 例　入力a=10, 入力b=-1  差c=11<br>
# 例　入力a=-10, 入力b=-1  差c=9<br>

# %%
#課題5のプログラムをここに書く
a=int(input())
b=int(input())
if a>b:
  c=a-b
elif b>a:
  c=b-a
print("差=",c)
# Out:
# -10
# -1
# 差= 9

# %% [markdown]
# 課題6 3つの入力について、一番大きい値を出力するプログラムを作成せよ。<br>
# 例　入力a=1, 入力b=3, 入力c=-2 max=3<br>
# 論理演算andはこのプログラムでは使わない

# %%
#課題6のプログラムをここに書く
a=int(input())
b=int(input())
c=int(input())
if a>b:
  if a>c:
    max=a
  else:
    max=c
if b>a:
  if b>c:
    max=b
  else:
    max=c

print("max=",max)
# Out:
# 3
# 2
# 1
# max= 3

# %% [markdown]
# # 3_2 論理演算

# %% [markdown]
# (1)==を計算させると出力は？<br>
# 3==3

# %%
3==3
# Out:
# True

# %% [markdown]
# (2)==を処理すると出力は？<br>
# 3==-1

# %%
3==-1
# Out:
# False

# %% [markdown]
# (3)変数の値を比較して、その結果がTrueやFalseになる。
# ```
# a=1
# b=-1
# a>b
# ```
# a>b以外に、a==b, a<b, a>=b, a<=b, a!=bも試してみてください。

# %%
a=1
b=-1
a>b
# Out:
# True

# %% [markdown]
# (4)ifの中の条件評価部分の値の扱いを考えよう。<br>
# (a>b)がTrueなら、直後の処理を<br>
# (a>b)がFalseなら、else後の処理を実行<br>

# %%
a=1
b=2
if(a>b):
  print("Trueと判定されている。")
else:
  print("Falseと判定されている。")
# Out:
# Falseと判定されている。

# %% [markdown]
# (5) 論理積 and<br>
# 2つの条件が共にTrueであればTrueと評価する。<br>
# (a > 0) and (b > 0)<br>
#  True   and  True => True　と評価

# %%
a=1
b=-3

if (a>0)and(b>0):
  print("共に正")
else:
  print("負が混じっている")
# Out:
# 負が混じっている

# %% [markdown]
# 課題7 ifの中にifがあるが、これをandを使って<br>
# ifの中にifを無くしたプログラムを作成せよ。
# ```
# a = 1
# b = -1
# if (a>0):
#   if(b > 0):
#     print("ともに正")
#   else:
#     print("aが正、bが負")
# else:
#   if(b > 0):
#     print("aが負、bが正")
#   else:
#     print("ともに負")
# print("a=",a)
# print("b=",b)
# ```
#
#
# ```
# a = 1
# b = -1
# if
#   print("ともに正")
# elif:
#   print("aが正、bが負")
# elif:
#   print("aが負、bが正")
# else:
#   print("ともに負")
# print("a=",a)
# print("b=",b)
# ```

# %%
#課題7のプログラムをここに書く
a = -1
b = 1
if ( a > 0) and ( b > 0):
    print("ともに正")
elif ( a > 0 ) and ( b < 0):
    print("aが正、bが負")
elif ( a < 0 ) and ( b > 0):
  print("aが負、bが正")
else:
    print("ともに負")
print("a=",a)
print("b=",b)
# Out:
# aが負、bが正
# a= -1
# b= 1

# %% [markdown]
# 課題8<br>
# 3のデータa,b,cを入力したときに、最小値を出力する<br>
# プログラムを作成せよ。<br>
# 論理演算andを使い、ifの中にifは使わないで書く。<br>

# %%
#課題8のプログラムをここに書く
a=int(input())
b=int(input())
c=int(input())

if(a<b and a<c):
  min = a
elif(b < a and b < c):
  min = b
else:
  min = c

print("最小値は、{}です。".format(min))
# Out:
# 3
# 1
# 2
# 最小値は、1です。

# %% [markdown]
# 課題9 入力をscoreとし、scoreの範囲が、<br>
# 0より小さい、または100より大きなら"error"<br>
# 0以上60未満なら、"不合格"<br>
# 60以上100なら、"合格"<br>
# を出力するプログラムを作成しなさい。

# %%
#課題9のプログラムをここに書く
score = int(input())

if (score < 0 or score > 100):
  print("error")
elif(score >=0 and score <60):
  print("不合格")
elif(score >= 60 and score <=100):
  print("合格")
# Out:
# 50
# 不合格

# %% [markdown]
# (1)単純にn回繰り返す<br>
# ```
# for　i in range(n):
# で、range(n)で0～n-1までiに1ずつ増やして
# 繰り返す。
# range(1,n)で0～n-1までiに1ずつ増やす。
# range(1,n+1)で0～nまでiに1ずつ増やす。
# range(1,n,2)で0～n-1までiに2ずつ増やす。
# ```
# 下のプログラムは、nまでちゃんと足せていないので間違いです。

# %%
n = int(input())

sum=0
for i in range(n):
  sum += i
print("{}の総和={}".format(n,sum))
# Out:
# 10
# 10の総和=45

# %% [markdown]
# 課題10<br>
# 入力nの奇数の総和と、偶数の総和を<br>
# 出力するプログラムを作成せよ。

# %%
n = int(input())

sum_o=0
sum_e=0

for i in range(1,n+1,2):
  sum_o += i
for i in range(2,n+1,2):
  sum_e +=i

print("奇数の総和=", sum_o)
print("偶数の総和=", sum_e)
# Out:
# 10
# 奇数の総和= 25
# 偶数の総和= 30

# %% [markdown]
# (2)リストから繰り返しを実行する。<br>
# forの中にifを書いた場合

# %%
sum_e=0
for i in [1, 3, 7, 6, 2]:
  if i % 2 == 0:
    sum_e += i
print("リストの偶数の総和=",sum_e)
# Out:
# リストの偶数の総和= 8

# %% [markdown]
# 課題11<br>
# リストの負である数の個数を出力するプログラムを作成せよ。

# %%
nega=0

for i in [1, -3, 7, 8, -0.1, 7, -20]:
  if i < 0:
    nega += 1
print("負の個数=", nega)
# Out:
# 負の個数= 3

# %% [markdown]
# 課題12
# リストの正の数の合計を出力するプログラムを作成せよ。

# %%
sum_p=0

for i in [1, -3, 7, 8, 0.1, 7, -20]:
  if i >= 0:
    sum_p += i
print("0以上の合計=", sum_p)
# Out:
# 0以上の合計= 23.1
